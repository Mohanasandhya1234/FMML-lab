# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohanasandhya1234/FMML-lab/blob/main/Module_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-26 13:44:17--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   108MB/s    in 0.6s
#
# 2024-03-26 13:44:18 (108 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 3156    1303.5913v1  Robust visual tracking for long video sequence...    cs
# 9167   1511.03546v4  Much of information sits in an unprecedented a...    cs
# 26645  1611.05588v1  Effective image and sentence matching depends ...    cs
# 22281  1511.07294v1  We consider convex-concave saddle point proble...  stat
# 21832   1302.4853v2  As a testament to their success, the theory of...  stat
# ...             ...                                                ...   ...
# 6486   1702.07780v1  Machine learning models are often used at test...  stat
# 13528   1207.0702v1  A significantly under-explored area of evoluti...    cs
# 35750   1203.3484v1  This paper addresses the problem of sampling f...  stat
# 37858   0908.1258v1  We propose a family of statistical models for ...  stat
# 13283   0705.0602v1  The assessment of highly-risky situations at r...    cs
#
#                                                    title  year  \
# 3156   A Diffusion Process on Riemannian Manifold for...  2013
# 9167   Hierarchical Latent Semantic Mapping for Autom...  2015
# 26645  Instance-aware Image and Sentence Matching wit...  2016
# 22281  Stochastic Parallel Block Coordinate Descent f...  2015
# 21832               Consistency of Online Random Forests  2013
# ...                                                  ...   ...
# 6486   Changing Model Behavior at Test-Time Using Rei...  2017
# 13528  Meme as Building Block for Evolutionary Optimi...  2012
# 35750  Intracluster Moves for Constrained Discrete-Sp...  2012
# 37858        Discrete Temporal Models of Social Networks  2009
# 13283  Risk Assessment Algorithms Based On Recursive ...  2007
#
#                                                 keywords
# 3156   [sequences, important, applications, challenge...
# 9167   [information, unprecedented, allocation, impor...
# 26645  [effective, similarity, observation, similarit...
# 22281  [separable, structure, functions, efficient, s...
# 21832  [testament, application, narrowing, providing,...
# ...                                                  ...
# 6486   [constraints, operating, inference, translatio...
# 13528  [significantly, evolutionary, optimization, li...
# 35750  [addresses, distributions, constraints, partic...
# 37858  [statistical, evolution, represents, extension...
# 13283  [assessment, situations, intersections, import...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 3156     [sequences, important, applications, challenge...
# 9167     [information, unprecedented, allocation, impor...
# 26645    [effective, similarity, observation, similarit...
# 22281    [separable, structure, functions, efficient, s...
# 21832    [testament, application, narrowing, providing,...
#                                ...
# 6520     [nonlinear, architectures, perturbations, vuln...
# 31838    [challenging, correlated, variables, dimension...
# 23382    [reduction, corrupted, presented, efficiently,...
# 6366     [algorithms, optimized, prediction, naturally,...
# 10535    [factorization, approximates, extensions, dive...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8840 words.
# Out of those 4641 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="da9507af-d343-4c33-88df-1d062dfc15d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da9507af-d343-4c33-88df-1d062dfc15d6")) {                    Plotly.newPlot(                        "da9507af-d343-4c33-88df-1d062dfc15d6",                        [{"x":["dynamical","challenges","transformed","sequential","inference","riemannian","experiments","applications","algorithm","descriptors","uncertainties","comparable","outperformed","kinematic","component","important","posterior","constraints","transformation","incremental","diffusion","sequences","particularly","principled","principal","performance","semidefinite","distribution","variations","illumination","covariance","misalignment","descriptor","introduce","generative","maintained","inherently","specified","sensitive","detection","association","generating","demonstrate","constructs","automatically","calculates","hierarchical","unprecedented","extending","algorithms","traditional","resembles","improving","unipartite","hierarchically","allocation","generates","approaches","community","automated","information","generation","effective","collections","promising","communities","experimental","comparisons","predicting","attention","aggregates","observation","multimodal","selectively","similarity","representations","instances","similarities","measuring","modulated","selective","benchmark","similarly","extensive","predicted","aggregation","sequentially","stochastic","structure","efficiency","including","optimization","separable","selection","simplicity","significantly","flexibility","coordinate","utilizing","functions","empirically","efficient","theoretically","providing","narrowing","application","consistency","relational","correspond","dimensional","correlation","multivariate","associated","attribute","variables","attributes","characterized","categorical","inferring","construction","contribution","computational","descendant","construct","efficiently","guaranteed","advantage","searching","predictive","screening","development","corresponding","recognition","investigating","techniques","conditions","investigation","implementations","challenging","neuromorphic","platforms","incorporating","navigation","potential","possibility","computing","extremely","implementation","hierarchy","identified","recognize","classification","predictions","framework","emotional","performed","intrinsic","classified","individual","classifying","corresponds","minimizing","minimization","likelihood","outperforms","divergence","gradients","considered","generalizes","translation","objective","reinforcement","uncertainty","consistent","restricted","empirical","monocular","detections","imperfect","reasonable","anatomical","compositional","generalize","evaluation","occlusion","ambiguity","hypotheses","combining","literature","plausible","anatomically","intrinsically","conditioned","additionally","synthesis","induction","dependent","significant","representation","inputoutput"],"y":[22,108,26,73,240,10,620,435,820,47,7,104,15,8,93,373,38,164,60,29,27,106,74,29,33,899,7,230,80,42,21,3,29,336,107,10,21,34,51,340,37,107,544,17,180,1,106,8,35,588,174,5,103,2,10,31,66,492,70,83,705,149,237,20,107,28,378,25,85,173,9,75,27,5,132,249,91,38,32,4,18,201,14,166,42,30,22,143,339,168,243,303,15,136,31,275,33,28,37,207,79,408,43,82,2,248,55,33,32,210,74,20,100,37,123,64,26,16,27,68,79,286,1,88,153,38,78,22,58,5,146,103,383,14,372,146,28,45,274,9,23,48,17,144,40,137,52,124,38,47,45,506,88,576,8,122,52,20,126,33,34,46,57,55,259,23,29,121,30,109,134,115,87,93,53,135,22,14,12,32,8,28,56,264,27,24,33,91,130,27,2,12,26,67,48,22,81,226,401,2],"type":"bar"},{"x":["dynamical","challenges","transformed","sequential","inference","riemanni ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4641,), (4641, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7966666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Managing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Distributed</span> <span style=''>MARF</span> <span style=''>with</span> <span style=''>SNMP</span> <br/><br/><span style=''>The</span> <span style=''>scope</span> <span style=''>of</span> <span style=''>this</span> <span style=''>projects</span> <span style=''>work</span> <span style=''>focuses</span> <span style=''>on</span> <span style=''>the</span> <span style=''>research</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>prototyping</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extension</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Distributed</span> <span style=''>MARF</span> <span style=''>such</span> <span style=''>that</span> <span style=''>its</span> <span style=''>services</span> <span style=''>can</span> <span style=''>be</span> <span style=''>managed</span> <span style=''>through</span> <span style=''>the</span> <span style=''>most</span> <span style=''>popular</span> <span style='background-color:rgba(0, 255, 0, 0.6206896551724138);'>management</span> <span style=''>protocol</span> <span style=''>familiarly</span> <span style=''>SNMP</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>rationale</span> <span style=''>behind</span> <span style=''>SNMP</span> <span style=''>vs</span> <span style=''>MARFs</span> <span style='background-color:rgba(255, 0, 0, 0.6);'>proprietary</span> <span style='background-color:rgba(0, 255, 0, 0.6206896551724138);'>management</span> <span style='background-color:rgba(0, 255, 0, 0.39999999999999997);'>protocols</span> <span style=''>is</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3499999999999999);'>integrated</span> <span style=''>with</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style=''>common</span> <span style=''>network</span> <span style=''>service</span> <span style=''>and</span> <span style=''>device</span> <span style='background-color:rgba(0, 255, 0, 0.6206896551724138);'>management</span> <span style=''>so</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>administrators</span> <span style=''>can</span> <span style=''>manage</span> <span style=''>MARF</span> <span style=''>nodes</span> <span style=''>via</span> <span style=''>a</span> <span style=''>already</span> <span style=''>familiar</span> <span style=''>protocol</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>monitor</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>gather</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>statistics</span> <span style=''>set</span> <span style=''>desired</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>configuration</span> <span style=''>etc</span> <span style=''>perhaps</span> <span style=''>using</span> <span style=''>the</span> <span style=''>same</span> <span style='background-color:rgba(0, 255, 0, 0.6206896551724138);'>management</span> <span style=''>tools</span> <span style=''>theyve</span> <span style=''>been</span> <span style=''>using</span> <span style=''>for</span> <span style=''>other</span> <span style=''>network</span> <span style=''>devices</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>application</span> <span style=''>servers</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Bayesian</span> <span style=''>Learning</span> <span style=''>for</span> <span style=''>Low</span> <span style=''>Rank</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstruction</span> <br/><br/><span style=''>We</span> <span style=''>develop</span> <span style=''>latent</span> <span style=''>variable</span> <span style=''>models</span> <span style=''>for</span> <span style=''>Bayesian</span> <span style=''>learning</span> <span style=''>based</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>completion</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstruction</span> <span style=''>from</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurements</span> <span style=''>For</span> <span style=''>under</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>determined</span> <span style=''>systems</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developed</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>shown</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstruct</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>matrices</span> <span style=''>when</span> <span style=''>neither</span> <span style=''>the</span> <span style=''>rank</span> <span style=''>nor</span> <span style=''>the</span> <span style=''>noise</span> <span style=''>power</span> <span style=''>is</span> <span style=''>known</span> <span style=''>a</span> <span style=''>priori</span> <span style=''>We</span> <span style=''>derive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relations</span> <span style=''>between</span> <span style=''>the</span> <span style=''>latent</span> <span style=''>variable</span> <span style=''>models</span> <span style=''>and</span> <span style=''>several</span> <span style=''>low</span> <span style=''>rank</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>promoting</span> <span style=''>penalty</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relations</span> <span style=''>justify</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Kronecker</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style=''>matrices</span> <span style=''>in</span> <span style=''>a</span> <span style=''>Gaussian</span> <span style=''>based</span> <span style=''>prior</span> <span style=''>In</span> <span style=''>the</span> <span style=''>methods</span> <span style=''>we</span> <span style=''>use</span> <span style=''>evidence</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expectation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maximization</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>the</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>the</span> <span style=''>methods</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluated</span> <span style=''>through</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extensive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>numerical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulations</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>DinTucker</span> <span style=''>Scaling</span> <span style=''>up</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>models</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multidimensional</span> <span style=''>arrays</span> <span style=''>with</span> <span style=''>billions</span> <span style=''>of</span> <span style=''>elements</span> <br/><br/><span style=''>Infinite</span> <span style=''>Tucker</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Decomposition</span> <span style=''>(InfTucker)</span> <span style=''>and</span> <span style=''>random</span> <span style=''>function</span> <span style=''>prior</span> <span style=''>models</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.7391304347826086);'>nonparametric</span> <span style=''>Bayesian</span> <span style=''>models</span> <span style=''>on</span> <span style=''>infinite</span> <span style='background-color:rgba(255, 0, 0, 0.7142857142857142);'>exchangeable</span> <span style=''>arrays</span> <span style=''>are</span> <span style=''>more</span> <span style=''>powerful</span> <span style=''>models</span> <span style=''>than</span> <span style=''>widely</span> <span style=''>used</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multilinear</span> <span style='background-color:rgba(255, 0, 0, 0.35000000000000014);'>factorization</span> <span style=''>methods</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style=''>Tucker</span> <span style=''>and</span> <span style=''>PARAFAC</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposition</span> <span style=''>(partly)</span> <span style=''>due</span> <span style=''>to</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.5466666666666666);'>capability</span> <span style=''>of</span> <span style=''>modeling</span> <span style='background-color:rgba(255, 0, 0, 0.38372093023255816);'>nonlinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relationships</span> <span style=''>between</span> <span style=''>array</span> <span style=''>elements</span> <span style=''>Despite</span> <span style=''>their</span> <span style=''>great</span> <span style='background-color:rgba(255, 0, 0, 0.42000000000000004);'>predictive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>and</span> <span style=''>sound</span> <span style='background-color:rgba(255, 0, 0, 0.36507936507936506);'>theoretical</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>foundations</span> <span style=''>they</span> <span style=''>cannot</span> <span style=''>handle</span> <span style=''>massive</span> <span style=''>data</span> <span style=''>due</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prohibitively</span> <span style=''>high</span> <span style=''>training</span> <span style=''>time</span> <span style=''>To</span> <span style=''>overcome</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3617021276595743);'>limitation</span> <span style=''>we</span> <span style=''>present</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Distributed</span> <span style=''>Infinite</span> <span style=''>Tucker</span> <span style=''>(DINTUCKER)</span> <span style=''>a</span> <span style=''>large</span> <span style=''>scale</span> <span style='background-color:rgba(255, 0, 0, 0.38372093023255816);'>nonlinear</span> <span style=''>tensor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposition</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>MAPREDUCE</span> <span style=''>While</span> <span style='background-color:rgba(0, 255, 0, 0.30909090909090897);'>maintaining</span> <span style=''>th ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Compressed</span> <span style=''>Sensing</span> <span style=''>Based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Decomposition</span> <span style=''>of</span> <span style=''>Electrodermal</span> <span style=''>Activity</span> <span style=''>Signals</span> <br/><br/><span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurement</span> <span style=''>and</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>Electrodermal</span> <span style=''>Activity</span> <span style=''>(EDA)</span> <span style=''>offers</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>in</span> <span style=''>diverse</span> <span style=''>areas</span> <span style=''>ranging</span> <span style=''>from</span> <span style=''>market</span> <span style=''>research</span> <span style=''>to</span> <span style=''>seizure</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>to</span> <span style=''>human</span> <span style=''>stress</span> <span style=''>analysis</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Unfortunately</span> <span style=''>the</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>EDA</span> <span style=''>signals</span> <span style=''>is</span> <span style=''>made</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>superposition</span> <span style=''>of</span> <span style=''>numerous</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>components</span> <span style=''>which</span> <span style=''>can</span> <span style=''>obscure</span> <span style=''>the</span> <span style=''>signal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>related</span> <span style=''>to</span> <span style=''>a</span> <span style=''>users</span> <span style=''>response</span> <span style=''>to</span> <span style=''>a</span> <span style=''>stimulus</span> <span style=''>We</span> <span style=''>show</span> <span style=''>how</span> <span style=''>simple</span> <span style=''>pre</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>followed</span> <span style=''>by</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>compressed</span> <span style=''>sensing</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style=''>can</span> <span style=''>mitigate</span> <span style=''>the</span> <span style=''>effects</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>undesired</span> <span style=''>noise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>components</span> <span style=''>and</span> <span style=''>help</span> <span style=''>reveal</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>physiological</span> <span style=''>signal</span> <span style=''>The</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>allows</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style=''>of</span> <span style=''>EDA</span> <span style=''>signals</span> <span style=''>with</span> <span style=''>provable</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''>the</span> <span style=''>recovery</span> <span style=''>of</span> <span style=''>user</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>responses</span> <span style=''>We</span> <span style=''>test</span> < ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	segmentation (0.07150480256136606)
# 	architecture (0.08929206688011383)
# 	information (0.2508004268943437)
# 	processing (0.11170401992173604)
# 	experimental (0.1344717182497332)
# 	representation (0.14265385983635717)
# 	detection (0.12095339736748488)
# 	different (0.2671647100675916)
# 	convolutional (0.13091426538598364)
# 	recognition (0.13625044468160796)
#
# Some Statistics words are:
# 	stochastic (0.13775766716943189)
# 	statistical (0.15284062342885874)
# 	estimation (0.1689291101055807)
# 	algorithm (0.39316239316239315)
# 	theoretical (0.15133232780291603)
# 	variables (0.1478129713423831)
# 	inference (0.19205630970336854)
# 	distribution (0.18903971845148315)
# 	dimensional (0.1845148315736551)
# 	regression (0.17647058823529413)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ed3898c4-f674-4d9e-9846-5253d911ff5b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ed3898c4-f674-4d9e-9846-5253d911ff5b")) {                    Plotly.newPlot(                        "ed3898c4-f674-4d9e-9846-5253d911ff5b",                        [{"x":["dynamical","challenges","transformed","sequential","inference","riemannian","experiments","applications","algorithm","descriptors","uncertainties","comparable","outperformed","kinematic","component","important","posterior","constraints","transformation","incremental","diffusion","sequences","particularly","principled","principal","performance","semidefinite","distribution","variations","illumination","covariance","misalignment","descriptor","introduce","generative","maintained","inherently","specified","sensitive","detection","association","generating","demonstrate","constructs","automatically","calculates","hierarchical","unprecedented","extending","algorithms","traditional","resembles","improving","unipartite","hierarchically","allocation","generates","approaches","community","automated","information","generation","effective","collections","promising","communities","experimental","comparisons","predicting","attention","aggregates","observation","multimodal","selectively","similarity","representations","instances","similarities","measuring","modulated","selective","benchmark","similarly","extensive","predicted","aggregation","sequentially","stochastic","structure","efficiency","including","optimization","separable","selection","simplicity","significantly","flexibility","coordinate","utilizing","functions","empirically","efficient","theoretically","providing","narrowing","application","consistency","relational","correspond","dimensional","correlation","multivariate","associated","attribute","variables","attributes","characterized","categorical","inferring","construction","contribution","computational","descendant","construct","efficiently","guaranteed","advantage","searching","predictive","screening","development","corresponding","recognition","investigating","techniques","conditions","investigation","implementations","challenging","neuromorphic","platforms","incorporating","navigation","potential","possibility","computing","extremely","implementation","hierarchy","identified","recognize","classification","predictions","framework","emotional","performed","intrinsic","classified","individual","classifying","corresponds","minimizing","minimization","likelihood","outperforms","divergence","gradients","considered","generalizes","translation","objective","reinforcement","uncertainty","consistent","restricted","empirical","monocular","detections","imperfect","reasonable","anatomical","compositional","generalize","evaluation","occlusion","ambiguity","hypotheses","combining","literature","plausible","anatomically","intrinsically","conditioned","additionally","synthesis","induction","dependent","significant","representation","inputoutput","semantics","engineered","importantly","competing","automatic","specification","deformable","alignment","challenge","imprecise","augmentation","landmarks","reconstruct","improvement","difficult","innovative","undetected","reconstruction","conjunction","competition","perfectly","conference","theoretical","optimizing","selecting","simulations","prediction","excellent","presented","technique","convergence","estimation","reproducing","estimated","developed","especially","confirmed","nonlinear","acyclicity","answering","resulting","reasoners","prominent","establish","sufficient","databases","evaluated","guarantees","practically","landscape","necessarily","undecidable","fragments","ontologies","summarising","investigate","existential","termination ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	heteroscedasticity
# 	roadworks
# 	unobservable
# 	unmeasured
# 	sufficiency
# 	contamination
# 	unspecified
# 	semiparametric
# 	thermodynamic
# 	thurstone
# 	forecasted
# 	distributionally
# 	ancestral
# 	tightness
# 	mitigates
# 	photovoltaic
# 	calculable
# 	procrustes
# 	crowdworkers
# 	interfacing
# Some words which never appear in Statistics papers:
# 	neuromorphic
# 	monocular
# 	imperfect
# 	undetected
# 	reasoners
# 	undecidable
# 	ontologies
# 	summarising
# 	existential
# 	termination
# 	terminates
# 	fluorescent
# 	blackboard
# 	reflections
# 	participate
# 	accommodated
# 	administrators
# 	turbulence
# 	inflection
# 	imitating

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.053341882690605e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7641666666666667
